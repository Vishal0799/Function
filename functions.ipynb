# %% [markdown]
# # Functions
#
# **Q1. What is the difference between a function and a method in Python?**
#
#   In Python, both functions and methods are blocks of code that can be executed multiple times from different parts of your program. However, there are key differences between them:
#
# **Functions**
# - A function is a self-contained block of code that performs a specific task.
# - It is not associated with any class or object.
# - Functions are defined using the def keyword.
#
# **Methods**
# - A method is a block of code that is associated with a class or object.
# - It is used to perform actions on an object or to modify its state.
# - Methods are also defined using the def keyword, but they are inside a class definition.
#
# **Example:**
#
# # Function
# def greet(name):
#
#     print(f"Hello, {name}!")
#
# # Method
# class Person:
#
#     def __init__(self, name):
#         self.name = name
#
#     def greet(self):
#         print(f"Hello, my name is {self.name}!")
#
# **Q2. Explain the concept of function arguments and parameters in Python.**
#
# In Python, when defining a function, you can specify arguments that the function can accept when it's called. These arguments are also known as parameters.
#
# **Function Parameters:**
#
# - Parameters are the variables defined in the function definition.
# - They are used to receive the input values passed to the function.
# - Parameters are local to the function and are not accessible outside the function.
#
# **Function Arguments:**
#
# - Arguments are the actual values passed to the function when it's called.
# - They are assigned to the corresponding parameters in the function definition.
# - Arguments can be literals, variables, or expressions.
#
# **Example:**
#
# def greet(name, age):
#
#     print(f"Hello, {name}! You are {age} years old.")
#
#  **Calling the function with arguments**
#
# greet("John", 30)
#
# **Types of Function Arguments:**
#
# - **Positional arguments:** These are arguments that are passed to the function in the same order as the parameters are defined. (e.g., greet("John", 30))
# - **Keyword arguments:** These are arguments that are passed to the function using the parameter name followed by an equals sign and the value. (e.g., greet(name="John", age=30))
# - **Default arguments:** These are arguments that have a default value assigned to them in the function definition. (e.g., def greet(name, age=30): ...)
# - **Variable-length arguments:** These are arguments that can be passed to the function in a variable number of quantities. (e.g., def greet(name, *args): ...)
#
# **Q3. What are the different ways to define and call a function in Python?**
#
# In Python, there are several ways to define and call a function. Here are some examples:
#
# **Defining and Calling a Function**
#
# **1. Simple Function Definition and Call**
#
# def greet(name):
#     print(f"Hello, {name}!")
#
# greet("John")  # Output: Hello, John!
#
#
# **2. Function Definition with Return Statement**
#
# def add(a, b):
#     return a + b
#
# result = add(2, 3)
# print(result)  # Output: 5
#
#
# **3. Function Call with Keyword Arguments**
#
# def greet(name, age):
#     print(f"Hello, {name}! You are {age} years old.")
#
# greet(age=30, name="John")  # Output: Hello, John! You are 30 years old.
#
#
# **4. Function Call with Default Argument Values**
#
# def greet(name, age=30):
#     print(f"Hello, {name}! You are {age} years old.")
#
# greet("John")  # Output: Hello, John! You are 30 years old.
#
#
# **5. Function Call with Variable-Length Arguments**
#
# def greet(name, *args):
#     print(f"Hello, {name}!")
#     for arg in args:
#         print(arg)
#
# greet("John", "How are you?", "What's up?")
# # Output:
# # Hello, John!
# # How are you?
# # What's up?
#
#
# **6. Lambda Function Definition and Call**
#
# add = lambda a, b: a + b
# result = add(2, 3)
# print(result)  # Output: 5
#
#
# **7. Function Definition and Call using map(), filter(), and reduce()**
#
# from functools import reduce
#
# numbers = [1, 2, 3, 4, 5]
#
# **Using map()**
#
# squared_numbers = list(map(lambda x: x**2, numbers))
# print(squared_numbers)  # Output: [1, 4, 9, 16, 25]
#
# **Using filter()**
#
# even_numbers = list(filter(lambda x: x % 2 == 0, numbers))
# print(even_numbers)  # Output: [2, 4]
#
# **Using reduce()**
#
# sum_of_numbers = reduce(lambda x, y: x + y, numbers)
# print(sum_of_numbers)  # Output: 15
#
# **Q4. What is the purpose of the "return" statement in a Python function?**
#
# In Python, the return statement is used to exit a function and send a value back to the caller. The purpose of the return statement is to:
#
# 1. **Terminate the function:** When a return statement is encountered, the function execution stops, and the control returns to the caller.
# 2. **Send a value back:** The return statement can specify a value to be sent back to the caller. This value can be any Python object, such as a number, string, list, dictionary, etc.
#
# **Here is an example:**
#
# def add(a, b):
#     result = a + b
#     return result
#
#  **Call the function**
# sum = add(2, 3)
# print(sum)  # Output: 5
#
# **Q5. What are iterators in Python and how do they differ from iterables?**
#
# In Python, iterators and iterables are two related but distinct concepts.
#
# **Iterables:**
#
# An iterable is an object that can be iterated over, meaning it can be looped through or have its elements accessed one at a time. Examples of iterables include:
#
# - Lists: [1, 2, 3]
# - Tuples: (1, 2, 3)
# - Dictionaries: {"a": 1, "b": 2}
# - Sets: {1, 2, 3}
# - Strings: "hello"
#
# **Iterators:**
#
# An iterator is an object that keeps track of its position in an iterable and yields the next element each time it is called.
#
#  Iterators are created from iterables using the iter() function.
#
# **Here's an example:**
#
# my_list = [1, 2, 3]
# my_iter = iter(my_list)
#
# print(next(my_iter))  # Output: 1
#
# print(next(my_iter))  # Output: 2
#
# print(next(my_iter))  # Output: 3
#
# **Key differences between iterators and iterables:**
#
# - Iterables are the objects that can be iterated over, while iterators are the objects that do the iteration.
# - Iterables can be iterated over multiple times, while iterators can only be iterated over once.
# - Iterators keep track of their position in the iterable, while iterables do not.
#
# **Q6. Explain the concept of generators in Python and how they are defined.**
#
# **Generators:**
#
# **Definition:** Generators are a simple way to create iterators using functions and the yield keyword instead of returning values.
#
# **Key Points:**
#
# yield Keyword:
#
# **Yield vs. Return:** Unlike the return statement, which exits the function, yield returns a value and pauses the function’s state, allowing it to resume from where it left off.
# **Multiple Yields:** Functions can yield multiple values over time, producing a sequence of results.
#
# **Example**
#
# def my_generator():
#     for i in range(10):
#         yield i
#
# # Create an iterator from the generator
# my_iter = my_generator()
#
# # Retrieve the values generated by the generator
# for value in my_iter:
#     print(value)
#
# This will output the numbers from 0 to 9.
#
# **Q7. What are the advantages of using generators over regular functions?**
#
# Generators have several advantages over regular functions:
#
# 1. **Memory Efficiency:** Generators use significantly less memory than regular functions because they don't store all the values in memory at once. Instead, they generate values on-the-fly, which makes them ideal for handling large datasets.
#
# 2. **Lazy Evaluation:** Generators only compute values when they are needed, which is known as lazy evaluation. This approach can lead to significant performance improvements, especially when working with expensive computations.
#
# 3. **Flexibility:** Generators can be used to create complex, dynamic sequences that would be difficult or impossible to create with regular functions.
#
# 4. **Improved Performance:** Generators can improve performance by avoiding the need to create and store large data structures. This is especially important when working with large datasets or expensive computations.
#
# 5. **Easier Handling of Infinite Sequences:** Generators make it easy to handle infinite sequences, which would be impossible to handle with regular functions.
#
# 6. **Simplified Code:** Generators can simplify code by eliminating the need for explicit loops and conditional statements.
#
# 7. **Better Support for Cooperative Multitasking:** Generators provide better support for cooperative multitasking, which allows multiple tasks to run concurrently without the need for threads or processes.
#
# **Here's an example that demonstrates the memory efficiency of generators:**
#
# import sys
#
# **Create a list of numbers from 1 to 1 million**
#
#
# numbers_list = list(range(1, 1000001))
# print(f"Memory usage of list: {sys.getsizeof(numbers_list)} bytes")
#
#  **Create a generator that generates numbers from 1 to 1 million**
#
#
# numbers_generator = (x for x in range(1, 1000001))
# print(f"Memory usage of generator: {sys.getsizeof(numbers_generator)} bytes")
#
# **Q8. What is a lambda function in Python and when is it typically used?**
#
# **Lambda Functions:**
#
#  Lambda functions are small, anonymous functions defined using the lambda keyword. They are used for creating small, throwaway functions without the need to formally define a function using def
#
#  **Key Points:**
#
# **Anonymous:** Lambda functions are not bound to a name.
#
# **Single Expression:** They can contain only one expression, which is evaluated and returned.
#
# **Syntax:**
#
# lambda arguments: expression
#
#
#
# **Example:**
#
# double = lambda x: x * 2
#
# print(double(5))  # Output: 10
#
# In this example, the lambda function takes one argument x and returns its double.
#
# **When to use lambda functions:**
#
# 1. **One-time use:** Lambda functions are ideal for one-time use cases, such as when you need to pass a small function as an argument to another function.
# 2. **Simple transformations:** Lambda functions are great for simple transformations, such as converting data types or performing basic arithmetic operations.
# 3. **Event handling:** Lambda functions can be used as event handlers, such as when you need to respond to a button click or other user interaction.
# 4. **Data processing:** Lambda functions can be used to process data in a concise and efficient way, such as when working with lists, dictionaries, or other data structures.
#
# **Q9. Explain the purpose and usage of the `map()` function in Python.**
#
# The map() function in Python is a built-in function that applies a given function to each item of an iterable (such as a list, tuple, or string) and returns a list of the results.
#
# **Purpose:**
#
# **The map() function is used to:**
#
# 1. Apply a transformation to each element of an iterable.
# 2. Convert data from one format to another.
# 3. Perform element-wise operations on iterables.
#
# **Syntax:**
#
# map(function, iterable)
#
# Example 1: Squaring numbers
#
# numbers = [1, 2, 3, 4, 5]
# squared_numbers = list(map(lambda x: x ** 2, numbers))
# print(squared_numbers)  # Output: [1, 4, 9, 16, 25]
#
# **Q10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?**
#
# map(), reduce(), and filter() are three fundamental functions in Python that are used for data processing and transformation. Here's a brief overview of each function, along with examples:
#
# **1. map() function:**
#
# The map() function applies a given function to each item of an iterable (such as a list, tuple, or string) and returns a list of the results.
#
# **Syntax:** map(function, iterable)
#
# **Example:**
#
# numbers = [1, 2, 3, 4, 5]
# squared_numbers = list(map(lambda x: x ** 2, numbers))
# print(squared_numbers)  # Output: [1, 4, 9, 16, 25]
#
# **2. reduce() function:**
#
# The reduce() function applies a given function to the items of an iterable, going from left to right, so as to reduce the iterable to a single output.
#
# **Syntax:** reduce(function, iterable)
#
# **Example:**
#
# import functools
# numbers = [1, 2, 3, 4, 5]
# sum_of_numbers = functools.reduce(lambda x, y: x + y, numbers)
# print(sum_of_numbers)  # Output: 15
#
# Note: In Python 3.x, reduce() is moved to the functools module.
#
# **3. filter() function:**
#
# The filter() function constructs an iterator from elements of an iterable for which a function returns true.
#
# **Syntax:** filter(function, iterable)
#
# **Example:**
#
# numbers = [1, 2, 3, 4, 5]
# even_numbers = list(filter(lambda x: x % 2 == 0, numbers))
# print(even_numbers)  # Output: [2, 4]
#
# **Key differences:**
#
# - map() applies a function to each item of an iterable and returns a list of results.
# - reduce() applies a function to the items of an iterable, reducing it to a single output.
# - filter() constructs an iterator from elements of an iterable for which a function returns true.
#
# **Q11. Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given**
# **list:[47,11,42,13];**
#
# ![Functions image.jpeg](data:image/jpeg;base64,...)

# %%
# Practical Questions

#1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.
def sum_even_numbers(numbers):
    """
    Returns the sum of all even numbers in the input list.

    Args:
        numbers (list): A list of numbers.

    Returns:
        int: The sum of all even numbers in the list.
    """
    even_sum = 0
    for num in numbers:
        if num % 2 == 0:
            even_sum += num
    return even_sum

#2. Create a Python function that accepts a string and returns the reverse of that string.
def reverse_string(s):
    """
    Returns the reverse of the input string.

    Args:
        s (str): The input string.

    Returns:
        str: The reverse of the input string.
    """
    return s[::-1]

#3. Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.
def square_numbers(numbers):
    """
    Returns a new list containing the squares of each number in the input list.

    Args:
        numbers (list): A list of integers.

    Returns:
        list: A new list containing the squares of each number.
    """
    return [x ** 2 for x in numbers]

#4. Write a Python function that checks if a given number is prime or not from 1 to 200.
def is_prime(n):
    """
    Checks if a given number is prime or not.

    Args:
        n (int): The number to check.

    Returns:
        bool: True if the number is prime, False otherwise.
    """
    if n <= 1:
        return False
    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False
    return True

# Check numbers from 1 to 200
for i in range(1, 201):
    if is_prime(i):
        print(f"{i} is a prime number")

#5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.
 def __init__(self, n):
        """
        Initializes the Fibonacci iterator with the number of terms.

        Args:
            n (int): The number of terms in the Fibonacci sequence.
        """
        self.n = n
        self.a = 0
        self.b = 1
        self.current_term = 0

    def __iter__(self):
        """
        Returns the iterator object itself.
        """
        return self

    def __next__(self):
        """
        Returns the next term in the Fibonacci sequence.

        Raises:
            StopIteration: When the number of terms has been reached.
        """
        if self.current_term >= self.n:
            raise StopIteration

        result = self.a
        self.a, self.b = self.b, self.a + self.b
        self.current_term += 1
        return result

#6. Write a generator function in Python that yields the powers of 2 up to a given exponent.
def powers_of_two(exponent):
    """
    Yields the powers of 2 up to a given exponent.

    Args:
        exponent (int): The maximum exponent.

    Yields:
        int: The next power of 2.
    """
    for i in range(exponent + 1):
        yield 2 ** i

#7. Implement a generator function that reads a file line by line and yields each line as a string.
def read_file_lines(file_path):
    """
    Reads a file line by line and yields each line as a string.

    Args:
        file_path (str): The path to the file to read.

    Yields:
        str: The next line from the file.
    """
    with open(file_path, 'r') as file:
        for line in file:
            yield line.strip()

#8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.
# Define the list of tuples
tuples_list = [(1, 3), (4, 2), (3, 1), (2, 4)]

# Use the sorted function with a lambda function as the key
sorted_tuples = sorted(tuples_list, key=lambda x: x[1])

# Print the sorted list of tuples
print(sorted_tuples)

#9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.
# Define a function to convert Celsius to Fahrenheit
def celsius_to_fahrenheit(celsius):
    return (celsius * 9/5) + 32

# Define a list of temperatures in Celsius
celsius_temperatures = [0, 10, 20, 30, 40]

# Use map() to convert Celsius to Fahrenheit
fahrenheit_temperatures = list(map(celsius_to_fahrenheit, celsius_temperatures))

# Print the converted temperatures
print("Celsius Temperatures:", celsius_temperatures)
print("Fahrenheit Temperatures:", fahrenheit_temperatures)

#10. Create a Python program that uses `filter()` to remove all the vowels from a given string.
# Define a function to check if a character is a vowel
def is_vowel(char):
    vowels = 'aeiouAEIOU'
    return char in vowels

# Define a string
input_string = "Hello, World!"

# Use filter() to remove vowels from the string
result_string = "".join(filter(lambda char: not is_vowel(char), input_string))

# Print the result
print("Original String:", input_string)
print("String without Vowels:", result_string)

#11) Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:
# Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the product of the price per item and the quantity. The product should be increased by 10,- € if the value of the order is smaller than 100,00 €. Write a Python program using lambda and map.

orders = [ ["34587", "Learning Python, Mark Lutz", 4, 40.95],
           ["98762", "Programming Python, Mark Lutz", 5, 56.80],
           ["77226", "Head First Python, Paul Barry", 3,32.95],
           ["88112", "Einführung in Python3, Bernd Klein", 	3, 24.99]]

result = list(map(lambda x: (x[0], x[2] * x[3] + 10 if x[2] * x[3] < 100 else x[2] * x[3]), orders))
print(result)
